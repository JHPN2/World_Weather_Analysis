# %% [markdown]
# ## Create 2000 random Lat / Lng combos

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# ## Import citipy and get nearest cities

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lngs in lat_lngs:
    city = citipy.nearest_city(lat_lngs[0], lat_lngs[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %% [markdown]
# ## API call

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description'] # NOTE the [0] for 'XXX':[{'YYY:VVV',...}]   
        # Append the city information into city_data list.
        city_data.append(
                         {
                          "City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc
                         }
                        )

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | general luna
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | berezovka
# Processing Record 6 of Set 1 | cheney
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | tazovskiy
# Processing Record 10 of Set 1 | amapa
# Processing Record 11 of Set 1 | grindavik
# Processing Record 12 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 1 | nynashamn
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | lensk
# Processing Record 19 of Set 1 | pevek
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | half moon bay
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | maloy
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | taoudenni
# Processing Record 30 of Set 1 | tacuarembo
# Processing Record 31 of Set 1 | nantucket
# Processing Record 32 of Set 1 | ahuimanu
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | meulaboh
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | avera
# Processing Record 37 of Set 1 | port blair
# Processing Record 38 of Set 1 | nanortalik
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | fortuna
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | katsuura
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 1 | muisne
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | acapulco
# Processing Record 1 of Set 2 | ostrovnoy
# Processing Record 2 of Set 2 | udachnyy
# Processing Record 3 of Set 2 | nongan
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | olafsvik
# Processing Record 6 of Set 2 | kaeo
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | mooresville
# Processing Record 10 of Set 2 | tondano
# Processing Record 11 of Set 2 | fort saint james
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | rockhampton
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | dergachi
# Processing Record 16 of Set 2 | xushan
# Processing Record 17 of Set 2 | itigi
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | jiehu
# Processing Record 20 of Set 2 | ponta delgada
# Processing Record 21 of Set 2 | isangel
# Processing Record 22 of Set 2 | salamanca
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | urumqi
# Processing Record 27 of Set 2 | caucaia
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | lethem
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | kalulushi
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | baragua
# Processing Record 36 of Set 2 | margate
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | khoy
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | bouar
# Processing Record 43 of Set 2 | tokzar
# City not found. Skipping...
# Processing Record 44 of Set 2 | cidreira
# Processing Record 45 of Set 2 | saint george
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | abha
# Processing Record 48 of Set 2 | williams lake
# Processing Record 49 of Set 2 | kyabe
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | richards bay
# Processing Record 3 of Set 3 | nichinan
# Processing Record 4 of Set 3 | norman wells
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 7 of Set 3 | dong hoi
# Processing Record 8 of Set 3 | shingu
# Processing Record 9 of Set 3 | bonthe
# Processing Record 10 of Set 3 | multan
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | clyde river
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | turan
# Processing Record 15 of Set 3 | polican
# Processing Record 16 of Set 3 | keetmanshoop
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | beya
# Processing Record 19 of Set 3 | talnakh
# Processing Record 20 of Set 3 | tongling
# Processing Record 21 of Set 3 | san borja
# Processing Record 22 of Set 3 | kathmandu
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 3 | chuy
# Processing Record 25 of Set 3 | muros
# Processing Record 26 of Set 3 | zyryanka
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | port lincoln
# Processing Record 29 of Set 3 | palmerston
# Processing Record 30 of Set 3 | sao felix do xingu
# Processing Record 31 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | conceicao do mato dentro
# Processing Record 33 of Set 3 | vaini
# Processing Record 34 of Set 3 | palana
# Processing Record 35 of Set 3 | salalah
# Processing Record 36 of Set 3 | caravelas
# Processing Record 37 of Set 3 | jand
# Processing Record 38 of Set 3 | kapaa
# Processing Record 39 of Set 3 | saskylakh
# Processing Record 40 of Set 3 | ca mau
# Processing Record 41 of Set 3 | leon
# Processing Record 42 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 3 | college
# Processing Record 44 of Set 3 | praia da vitoria
# Processing Record 45 of Set 3 | yar-sale
# Processing Record 46 of Set 3 | new norfolk
# Processing Record 47 of Set 3 | rognan
# Processing Record 48 of Set 3 | thinadhoo
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | loandjili
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | nabire
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | ingleside
# Processing Record 8 of Set 4 | bucerias
# Processing Record 9 of Set 4 | tucumcari
# Processing Record 10 of Set 4 | pundaguitan
# Processing Record 11 of Set 4 | bolshaya murta
# City not found. Skipping...
# Processing Record 12 of Set 4 | cap malheureux
# Processing Record 13 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 4 | yaring
# Processing Record 15 of Set 4 | coruripe
# Processing Record 16 of Set 4 | cockburn town
# Processing Record 17 of Set 4 | kayerkan
# Processing Record 18 of Set 4 | mar del plata
# Processing Record 19 of Set 4 | berbera
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | ziro
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | basco
# Processing Record 24 of Set 4 | jacareacanga
# Processing Record 25 of Set 4 | sorland
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | maceio
# Processing Record 28 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 4 | mokrous
# Processing Record 30 of Set 4 | kirensk
# Processing Record 31 of Set 4 | glace bay
# Processing Record 32 of Set 4 | nikolskoye
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | saint anthony
# Processing Record 35 of Set 4 | koumra
# Processing Record 36 of Set 4 | yurimaguas
# Processing Record 37 of Set 4 | kijang
# Processing Record 38 of Set 4 | saldanha
# Processing Record 39 of Set 4 | prince rupert
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | mackenzie
# Processing Record 42 of Set 4 | vao
# Processing Record 43 of Set 4 | labuan
# Processing Record 44 of Set 4 | nambour
# Processing Record 45 of Set 4 | dukat
# Processing Record 46 of Set 4 | marfino
# Processing Record 47 of Set 4 | sarangani
# Processing Record 48 of Set 4 | katsina
# Processing Record 49 of Set 4 | manicore
# Processing Record 50 of Set 4 | hambantota
# Processing Record 1 of Set 5 | mayo
# Processing Record 2 of Set 5 | zhicheng
# Processing Record 3 of Set 5 | veshenskaya
# Processing Record 4 of Set 5 | shirvan
# Processing Record 5 of Set 5 | gobabis
# Processing Record 6 of Set 5 | albanel
# Processing Record 7 of Set 5 | bay roberts
# Processing Record 8 of Set 5 | narsaq
# Processing Record 9 of Set 5 | oksovskiy
# Processing Record 10 of Set 5 | kabare
# Processing Record 11 of Set 5 | ayan
# Processing Record 12 of Set 5 | santa cruz
# Processing Record 13 of Set 5 | chakulia
# Processing Record 14 of Set 5 | kogon
# Processing Record 15 of Set 5 | bend
# Processing Record 16 of Set 5 | tabou
# Processing Record 17 of Set 5 | evensk
# Processing Record 18 of Set 5 | aklavik
# Processing Record 19 of Set 5 | kalmunai
# Processing Record 20 of Set 5 | ponta do sol
# Processing Record 21 of Set 5 | delta
# Processing Record 22 of Set 5 | cayenne
# Processing Record 23 of Set 5 | teguise
# Processing Record 24 of Set 5 | labuhan
# Processing Record 25 of Set 5 | balod
# Processing Record 26 of Set 5 | kinston
# Processing Record 27 of Set 5 | motygino
# Processing Record 28 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 29 of Set 5 | kongolo
# Processing Record 30 of Set 5 | kalevala
# Processing Record 31 of Set 5 | lompoc
# Processing Record 32 of Set 5 | trairi
# Processing Record 33 of Set 5 | aswan
# Processing Record 34 of Set 5 | sabaudia
# Processing Record 35 of Set 5 | cherskiy
# Processing Record 36 of Set 5 | portoferraio
# Processing Record 37 of Set 5 | palmer
# Processing Record 38 of Set 5 | gornyye klyuchi
# Processing Record 39 of Set 5 | honningsvag
# Processing Record 40 of Set 5 | eureka
# Processing Record 41 of Set 5 | broome
# Processing Record 42 of Set 5 | bambous virieux
# Processing Record 43 of Set 5 | henties bay
# Processing Record 44 of Set 5 | san carlos
# Processing Record 45 of Set 5 | tyup
# Processing Record 46 of Set 5 | deputatskiy
# Processing Record 47 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 5 | nakusp
# Processing Record 49 of Set 5 | korla
# Processing Record 50 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 1 of Set 6 | matadi
# Processing Record 2 of Set 6 | tuatapere
# Processing Record 3 of Set 6 | sioux lookout
# Processing Record 4 of Set 6 | huambo
# Processing Record 5 of Set 6 | inirida
# Processing Record 6 of Set 6 | akyab
# Processing Record 7 of Set 6 | raudeberg
# Processing Record 8 of Set 6 | eraniel
# Processing Record 9 of Set 6 | dingle
# Processing Record 10 of Set 6 | nouadhibou
# Processing Record 11 of Set 6 | te anau
# Processing Record 12 of Set 6 | lasa
# Processing Record 13 of Set 6 | severo-kurilsk
# Processing Record 14 of Set 6 | durusu
# Processing Record 15 of Set 6 | constitucion
# Processing Record 16 of Set 6 | registro
# Processing Record 17 of Set 6 | qasigiannguit
# Processing Record 18 of Set 6 | naryan-mar
# Processing Record 19 of Set 6 | itambe
# Processing Record 20 of Set 6 | konyshevka
# Processing Record 21 of Set 6 | northam
# Processing Record 22 of Set 6 | port moresby
# Processing Record 23 of Set 6 | sistranda
# Processing Record 24 of Set 6 | pangnirtung
# Processing Record 25 of Set 6 | lebu
# Processing Record 26 of Set 6 | kaduqli
# Processing Record 27 of Set 6 | guerrero negro
# Processing Record 28 of Set 6 | rawlins
# Processing Record 29 of Set 6 | okhotsk
# Processing Record 30 of Set 6 | bani
# Processing Record 31 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 6 | amberley
# Processing Record 33 of Set 6 | pitimbu
# Processing Record 34 of Set 6 | lagoa
# Processing Record 35 of Set 6 | eyl
# Processing Record 36 of Set 6 | tessalit
# Processing Record 37 of Set 6 | sao filipe
# Processing Record 38 of Set 6 | mareeba
# Processing Record 39 of Set 6 | egvekinot
# Processing Record 40 of Set 6 | dudinka
# Processing Record 41 of Set 6 | civitavecchia
# Processing Record 42 of Set 6 | hasaki
# Processing Record 43 of Set 6 | merauke
# Processing Record 44 of Set 6 | krasnyy chikoy
# Processing Record 45 of Set 6 | okha
# Processing Record 46 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 6 | lima
# Processing Record 48 of Set 6 | faya
# Processing Record 49 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 6 | itoman
# Processing Record 1 of Set 7 | mayma
# Processing Record 2 of Set 7 | juneau
# Processing Record 3 of Set 7 | emborion
# Processing Record 4 of Set 7 | cuiluan
# Processing Record 5 of Set 7 | comodoro rivadavia
# Processing Record 6 of Set 7 | loikaw
# Processing Record 7 of Set 7 | bokhan
# Processing Record 8 of Set 7 | kasongo-lunda
# Processing Record 9 of Set 7 | ampanihy
# Processing Record 10 of Set 7 | najran
# Processing Record 11 of Set 7 | bonfim
# Processing Record 12 of Set 7 | independencia
# Processing Record 13 of Set 7 | dabat
# Processing Record 14 of Set 7 | hamilton
# Processing Record 15 of Set 7 | sabha
# Processing Record 16 of Set 7 | loukhi
# Processing Record 17 of Set 7 | saint-pierre
# Processing Record 18 of Set 7 | khotynets
# Processing Record 19 of Set 7 | puerto colombia
# Processing Record 20 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 7 | boende
# Processing Record 22 of Set 7 | dalby
# Processing Record 23 of Set 7 | bontang
# Processing Record 24 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 7 | poya
# Processing Record 26 of Set 7 | barreirinhas
# Processing Record 27 of Set 7 | gorlice
# Processing Record 28 of Set 7 | aripuana
# Processing Record 29 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 7 | lazaro cardenas
# Processing Record 31 of Set 7 | honiton
# Processing Record 32 of Set 7 | pasighat
# Processing Record 33 of Set 7 | abong mbang
# Processing Record 34 of Set 7 | coquimbo
# Processing Record 35 of Set 7 | myitkyina
# Processing Record 36 of Set 7 | dorado
# Processing Record 37 of Set 7 | cabinda
# Processing Record 38 of Set 7 | tasiilaq
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | moron
# Processing Record 41 of Set 7 | neiafu
# Processing Record 42 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 7 | soyo
# Processing Record 44 of Set 7 | jabinyanah
# Processing Record 45 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 46 of Set 7 | yuanping
# Processing Record 47 of Set 7 | hami
# Processing Record 48 of Set 7 | tigzirt
# Processing Record 49 of Set 7 | riverbank
# Processing Record 50 of Set 7 | cape canaveral
# Processing Record 1 of Set 8 | haines junction
# Processing Record 2 of Set 8 | grevena
# Processing Record 3 of Set 8 | klaksvik
# Processing Record 4 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 8 | kuli
# Processing Record 6 of Set 8 | vila velha
# Processing Record 7 of Set 8 | manokwari
# Processing Record 8 of Set 8 | kortkeros
# Processing Record 9 of Set 8 | gizo
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | vanavara
# Processing Record 12 of Set 8 | molteno
# Processing Record 13 of Set 8 | ilulissat
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | marzuq
# Processing Record 16 of Set 8 | airai
# Processing Record 17 of Set 8 | nome
# Processing Record 18 of Set 8 | vestmanna
# Processing Record 19 of Set 8 | lagos
# Processing Record 20 of Set 8 | yanam
# Processing Record 21 of Set 8 | marienburg
# Processing Record 22 of Set 8 | vostok
# Processing Record 23 of Set 8 | shah alam
# Processing Record 24 of Set 8 | porto belo
# Processing Record 25 of Set 8 | koulamoutou
# Processing Record 26 of Set 8 | pindiga
# Processing Record 27 of Set 8 | saint-louis
# Processing Record 28 of Set 8 | bubaque
# Processing Record 29 of Set 8 | huilong
# Processing Record 30 of Set 8 | samarai
# Processing Record 31 of Set 8 | caaguazu
# Processing Record 32 of Set 8 | kindu
# Processing Record 33 of Set 8 | chermoz
# Processing Record 34 of Set 8 | denizli
# Processing Record 35 of Set 8 | westport
# Processing Record 36 of Set 8 | kamenka
# Processing Record 37 of Set 8 | pryozerne
# Processing Record 38 of Set 8 | port hardy
# Processing Record 39 of Set 8 | la primavera
# Processing Record 40 of Set 8 | lenki
# City not found. Skipping...
# Processing Record 41 of Set 8 | tura
# Processing Record 42 of Set 8 | veraval
# Processing Record 43 of Set 8 | novoorsk
# Processing Record 44 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | icod de los vinos
# Processing Record 47 of Set 8 | sobolevo
# Processing Record 48 of Set 8 | murgab
# Processing Record 49 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 8 | ladario
# Processing Record 1 of Set 9 | lebedinyy
# Processing Record 2 of Set 9 | shelburne
# Processing Record 3 of Set 9 | karratha
# Processing Record 4 of Set 9 | beisfjord
# Processing Record 5 of Set 9 | emerald
# Processing Record 6 of Set 9 | kahului
# Processing Record 7 of Set 9 | oyama
# Processing Record 8 of Set 9 | san cristobal
# Processing Record 9 of Set 9 | hastings
# Processing Record 10 of Set 9 | kandrian
# Processing Record 11 of Set 9 | ugoofaaru
# Processing Record 12 of Set 9 | camacha
# Processing Record 13 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 14 of Set 9 | accrington
# Processing Record 15 of Set 9 | bowen
# Processing Record 16 of Set 9 | hondo
# Processing Record 17 of Set 9 | alta floresta
# Processing Record 18 of Set 9 | luderitz
# Processing Record 19 of Set 9 | pathein
# Processing Record 20 of Set 9 | auki
# Processing Record 21 of Set 9 | mackay
# Processing Record 22 of Set 9 | victoria
# Processing Record 23 of Set 9 | karaton
# Processing Record 24 of Set 9 | karoi
# Processing Record 25 of Set 9 | kita
# Processing Record 26 of Set 9 | virginia beach
# Processing Record 27 of Set 9 | fuyang
# Processing Record 28 of Set 9 | dauphin
# Processing Record 29 of Set 9 | saint-augustin
# Processing Record 30 of Set 9 | mastic beach
# Processing Record 31 of Set 9 | marsassoum
# Processing Record 32 of Set 9 | adrar
# Processing Record 33 of Set 9 | vermilion
# Processing Record 34 of Set 9 | san quintin
# Processing Record 35 of Set 9 | waipawa
# Processing Record 36 of Set 9 | zheleznodorozhnyy
# Processing Record 37 of Set 9 | sorong
# Processing Record 38 of Set 9 | le port
# Processing Record 39 of Set 9 | inuvik
# Processing Record 40 of Set 9 | carballo
# Processing Record 41 of Set 9 | manitouwadge
# Processing Record 42 of Set 9 | itaituba
# Processing Record 43 of Set 9 | aragarcas
# Processing Record 44 of Set 9 | finschhafen
# Processing Record 45 of Set 9 | tiksi
# Processing Record 46 of Set 9 | ahipara
# Processing Record 47 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 9 | touros
# Processing Record 49 of Set 9 | san pedro
# Processing Record 50 of Set 9 | rajgarh
# Processing Record 1 of Set 10 | padang
# Processing Record 2 of Set 10 | sandorfalva
# Processing Record 3 of Set 10 | west wendover
# Processing Record 4 of Set 10 | novyy urengoy
# Processing Record 5 of Set 10 | pacific grove
# Processing Record 6 of Set 10 | alekseyevka
# Processing Record 7 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 10 | kruisfontein
# Processing Record 9 of Set 10 | singaparna
# Processing Record 10 of Set 10 | orvieto
# Processing Record 11 of Set 10 | abu dhabi
# Processing Record 12 of Set 10 | boyolangu
# Processing Record 13 of Set 10 | omsukchan
# Processing Record 14 of Set 10 | pak phanang
# Processing Record 15 of Set 10 | xingcheng
# Processing Record 16 of Set 10 | tonj
# Processing Record 17 of Set 10 | suntar
# Processing Record 18 of Set 10 | barcelos
# Processing Record 19 of Set 10 | christchurch
# Processing Record 20 of Set 10 | lata
# Processing Record 21 of Set 10 | coihaique
# Processing Record 22 of Set 10 | lipari
# Processing Record 23 of Set 10 | vilhena
# Processing Record 24 of Set 10 | el campo
# Processing Record 25 of Set 10 | belaya gora
# Processing Record 26 of Set 10 | cabadiangan
# Processing Record 27 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 29 of Set 10 | kalabo
# Processing Record 30 of Set 10 | tautira
# Processing Record 31 of Set 10 | cururupu
# Processing Record 32 of Set 10 | bossembele
# City not found. Skipping...
# Processing Record 33 of Set 10 | olbia
# Processing Record 34 of Set 10 | burnie
# Processing Record 35 of Set 10 | camrose
# Processing Record 36 of Set 10 | darnah
# Processing Record 37 of Set 10 | nador
# Processing Record 38 of Set 10 | norrkoping
# Processing Record 39 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 40 of Set 10 | yumen
# Processing Record 41 of Set 10 | sisimiut
# Processing Record 42 of Set 10 | shenjiamen
# Processing Record 43 of Set 10 | kieta
# Processing Record 44 of Set 10 | suining
# Processing Record 45 of Set 10 | gusau
# Processing Record 46 of Set 10 | waingapu
# Processing Record 47 of Set 10 | chifeng
# Processing Record 48 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 10 | ayagoz
# Processing Record 50 of Set 10 | dharchula
# Processing Record 1 of Set 11 | lamu
# Processing Record 2 of Set 11 | lazarev
# Processing Record 3 of Set 11 | punta alta
# Processing Record 4 of Set 11 | voyvozh
# Processing Record 5 of Set 11 | laguna
# Processing Record 6 of Set 11 | yatou
# Processing Record 7 of Set 11 | eenhana
# Processing Record 8 of Set 11 | myanaung
# Processing Record 9 of Set 11 | luena
# Processing Record 10 of Set 11 | naberera
# Processing Record 11 of Set 11 | kamina
# Processing Record 12 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 11 | bahia blanca
# Processing Record 14 of Set 11 | luziania
# Processing Record 15 of Set 11 | mamallapuram
# Processing Record 16 of Set 11 | lukiv
# Processing Record 17 of Set 11 | tilichiki
# Processing Record 18 of Set 11 | sao sebastiao
# Processing Record 19 of Set 11 | kabo
# Processing Record 20 of Set 11 | point pleasant
# Processing Record 21 of Set 11 | dabakala
# Processing Record 22 of Set 11 | kochetok
# Processing Record 23 of Set 11 | itarema
# Processing Record 24 of Set 11 | alofi
# Processing Record 25 of Set 11 | zhezkazgan
# Processing Record 26 of Set 11 | miraflores
# Processing Record 27 of Set 11 | corn island
# Processing Record 28 of Set 11 | brae
# Processing Record 29 of Set 11 | big spring
# Processing Record 30 of Set 11 | kyra
# Processing Record 31 of Set 11 | moose factory
# Processing Record 32 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 33 of Set 11 | keita
# Processing Record 34 of Set 11 | qurayyat
# Processing Record 35 of Set 11 | rio cuarto
# Processing Record 36 of Set 11 | yeppoon
# Processing Record 37 of Set 11 | lakki marwat
# Processing Record 38 of Set 11 | macau
# Processing Record 39 of Set 11 | khandyga
# Processing Record 40 of Set 11 | bayir
# Processing Record 41 of Set 11 | rorvik
# Processing Record 42 of Set 11 | ron
# Processing Record 43 of Set 11 | kisesa
# Processing Record 44 of Set 11 | umm kaddadah
# Processing Record 45 of Set 11 | san jose del guaviare
# Processing Record 46 of Set 11 | latung
# Processing Record 47 of Set 11 | astana
# Processing Record 48 of Set 11 | anadyr
# Processing Record 49 of Set 11 | tateyama
# Processing Record 50 of Set 11 | aguada de pasajeros
# Processing Record 1 of Set 12 | lafia
# Processing Record 2 of Set 12 | macklin
# Processing Record 3 of Set 12 | werda
# Processing Record 4 of Set 12 | sovetskiy
# Processing Record 5 of Set 12 | evanston
# Processing Record 6 of Set 12 | maniwaki
# Processing Record 7 of Set 12 | pangai
# Processing Record 8 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 9 of Set 12 | lavrentiya
# Processing Record 10 of Set 12 | viedma
# Processing Record 11 of Set 12 | linhares
# Processing Record 12 of Set 12 | yulara
# Processing Record 13 of Set 12 | belmonte
# Processing Record 14 of Set 12 | mbandaka
# Processing Record 15 of Set 12 | tevaitoa
# Processing Record 16 of Set 12 | chabahar
# Processing Record 17 of Set 12 | queanbeyan
# Processing Record 18 of Set 12 | buchanan
# Processing Record 19 of Set 12 | kardymovo
# Processing Record 20 of Set 12 | dawson creek
# Processing Record 21 of Set 12 | preston
# Processing Record 22 of Set 12 | poum
# Processing Record 23 of Set 12 | otukpo
# Processing Record 24 of Set 12 | los llanos de aridane
# Processing Record 25 of Set 12 | namatanai
# Processing Record 26 of Set 12 | nouakchott
# Processing Record 27 of Set 12 | upernavik
# Processing Record 28 of Set 12 | erzin
# Processing Record 29 of Set 12 | madisonville
# Processing Record 30 of Set 12 | la ronge
# Processing Record 31 of Set 12 | zhigansk
# Processing Record 32 of Set 12 | vardo
# Processing Record 33 of Set 12 | namibe
# Processing Record 34 of Set 12 | santa maria
# Processing Record 35 of Set 12 | rio grande
# Processing Record 36 of Set 12 | cap-aux-meules
# Processing Record 37 of Set 12 | lapas
# Processing Record 38 of Set 12 | ozerna
# Processing Record 39 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 12 | guadalupe y calvo
# Processing Record 41 of Set 12 | bodh gaya
# Processing Record 42 of Set 12 | colac
# Processing Record 43 of Set 12 | ta khmau
# Processing Record 44 of Set 12 | monrovia
# Processing Record 45 of Set 12 | north bend
# Processing Record 46 of Set 12 | kulhudhuffushi
# Processing Record 47 of Set 12 | ust-nera
# Processing Record 48 of Set 12 | ambilobe
# Processing Record 49 of Set 12 | buala
# Processing Record 50 of Set 12 | andenes
# Processing Record 1 of Set 13 | port-gentil
# Processing Record 2 of Set 13 | acarau
# Processing Record 3 of Set 13 | carutapera
# Processing Record 4 of Set 13 | bandarbeyla
# Processing Record 5 of Set 13 | iralaya
# Processing Record 6 of Set 13 | fare
# Processing Record 7 of Set 13 | taylor
# Processing Record 8 of Set 13 | benguela
# Processing Record 9 of Set 13 | buraydah
# Processing Record 10 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 13 | ballina
# Processing Record 12 of Set 13 | mpanda
# Processing Record 13 of Set 13 | voi
# Processing Record 14 of Set 13 | kurilsk
# Processing Record 15 of Set 13 | onega
# Processing Record 16 of Set 13 | thohoyandou
# Processing Record 17 of Set 13 | agirish
# Processing Record 18 of Set 13 | izumo
# Processing Record 19 of Set 13 | naze
# Processing Record 20 of Set 13 | llangefni
# Processing Record 21 of Set 13 | ixtapa
# Processing Record 22 of Set 13 | mogadishu
# Processing Record 23 of Set 13 | bafq
# Processing Record 24 of Set 13 | panguipulli
# Processing Record 25 of Set 13 | fairbanks
# Processing Record 26 of Set 13 | gondanglegi
# Processing Record 27 of Set 13 | biak
# Processing Record 28 of Set 13 | hoquiam
# Processing Record 29 of Set 13 | bonavista
# Processing Record 30 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 13 | hervey bay
# Processing Record 32 of Set 13 | nara
# Processing Record 33 of Set 13 | inta
# Processing Record 34 of Set 13 | fuxin
# Processing Record 35 of Set 13 | iisalmi
# Processing Record 36 of Set 13 | vershino-darasunskiy
# Processing Record 37 of Set 13 | breytovo
# Processing Record 38 of Set 13 | marawi
# Processing Record 39 of Set 13 | pucallpa
# Processing Record 40 of Set 13 | benjamin constant
# Processing Record 41 of Set 13 | the valley
# Processing Record 42 of Set 13 | lorengau
# Processing Record 43 of Set 13 | la orilla
# Processing Record 44 of Set 13 | crixas
# Processing Record 45 of Set 13 | sartell
# Processing Record 46 of Set 13 | mazabuka
# Processing Record 47 of Set 13 | nishihara
# Processing Record 48 of Set 13 | codrington
# Processing Record 49 of Set 13 | ikungi
# Processing Record 50 of Set 13 | tulle
# Processing Record 1 of Set 14 | aguimes
# Processing Record 2 of Set 14 | mehamn
# Processing Record 3 of Set 14 | ayna
# Processing Record 4 of Set 14 | tamandare
# Processing Record 5 of Set 14 | vinh long
# Processing Record 6 of Set 14 | calatayud
# Processing Record 7 of Set 14 | waidhofen
# Processing Record 8 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 14 | neuquen
# Processing Record 10 of Set 14 | corinto
# Processing Record 11 of Set 14 | vitim
# Processing Record 12 of Set 14 | guaymas
# Processing Record 13 of Set 14 | fez
# Processing Record 14 of Set 14 | shahreza
# Processing Record 15 of Set 14 | havre-saint-pierre
# Processing Record 16 of Set 14 | kutum
# Processing Record 17 of Set 14 | riyadh
# Processing Record 18 of Set 14 | san-pedro
# Processing Record 19 of Set 14 | kirkwood
# Processing Record 20 of Set 14 | kailua
# Processing Record 21 of Set 14 | khanpur
# Processing Record 22 of Set 14 | sunrise manor
# Processing Record 23 of Set 14 | puerto madryn
# Processing Record 24 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 25 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 14 | harper
# Processing Record 27 of Set 14 | ishinomaki
# Processing Record 28 of Set 14 | gushikawa
# Processing Record 29 of Set 14 | ribeira brava
# Processing Record 30 of Set 14 | belgrade
# Processing Record 31 of Set 14 | hearst
# Processing Record 32 of Set 14 | edwardsville
# Processing Record 33 of Set 14 | espana
# Processing Record 34 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 35 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 14 | kununurra
# Processing Record 37 of Set 14 | sangar
# Processing Record 38 of Set 14 | santa vitoria do palmar
# Processing Record 39 of Set 14 | vestmannaeyjar
# Processing Record 40 of Set 14 | matara
# Processing Record 41 of Set 14 | stokmarknes
# Processing Record 42 of Set 14 | hay river
# Processing Record 43 of Set 14 | anamur
# Processing Record 44 of Set 14 | port hueneme
# Processing Record 45 of Set 14 | chernyshevskiy
# Processing Record 46 of Set 14 | krasnovka
# Processing Record 47 of Set 14 | zhangjiakou
# Processing Record 48 of Set 14 | dolinsk
# Processing Record 49 of Set 14 | shimoda
# Processing Record 50 of Set 14 | nemuro
# Processing Record 1 of Set 15 | jinxiang
# Processing Record 2 of Set 15 | coos bay
# Processing Record 3 of Set 15 | husavik
# Processing Record 4 of Set 15 | moanda
# Processing Record 5 of Set 15 | necochea
# Processing Record 6 of Set 15 | kargil
# Processing Record 7 of Set 15 | amahai
# Processing Record 8 of Set 15 | atambua
# Processing Record 9 of Set 15 | iquique
# Processing Record 10 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 12 of Set 15 | moroni
# Processing Record 13 of Set 15 | kindia
# Processing Record 14 of Set 15 | sambava
# Processing Record 15 of Set 15 | kavaratti
# Processing Record 16 of Set 15 | xaxim
# Processing Record 17 of Set 15 | roald
# Processing Record 18 of Set 15 | lexington
# Processing Record 19 of Set 15 | seydi
# Processing Record 20 of Set 15 | batemans bay
# Processing Record 21 of Set 15 | banyo
# Processing Record 22 of Set 15 | skibbereen
# Processing Record 23 of Set 15 | praya
# Processing Record 24 of Set 15 | san andres
# Processing Record 25 of Set 15 | shubarkuduk
# Processing Record 26 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 15 | laranjeiras do sul
# Processing Record 28 of Set 15 | jahrom
# City not found. Skipping...
# Processing Record 29 of Set 15 | catio
# Processing Record 30 of Set 15 | ambunti
# Processing Record 31 of Set 15 | kargat
# Processing Record 32 of Set 15 | cove
# Processing Record 33 of Set 15 | qixia
# Processing Record 34 of Set 15 | mecca
# Processing Record 35 of Set 15 | xining
# Processing Record 36 of Set 15 | saint-joseph
# Processing Record 37 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 15 | qinzhou
# Processing Record 39 of Set 15 | leiyang
# Processing Record 40 of Set 15 | falmouth
# Processing Record 41 of Set 15 | nizhniy kuranakh
# Processing Record 42 of Set 15 | patiya
# Processing Record 43 of Set 15 | progreso
# Processing Record 44 of Set 15 | beloha
# Processing Record 45 of Set 15 | saravan
# Processing Record 46 of Set 15 | lyantonde
# Processing Record 47 of Set 15 | cabra
# Processing Record 48 of Set 15 | stephenville
# Processing Record 49 of Set 15 | wabash
# Processing Record 50 of Set 15 | belyy yar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  General Luna  13.6881  122.1708     75.56        90          87
# 1      Souillac -20.5167   57.5167     80.98        74          75
# 2  Longyearbyen  78.2186   15.6401     12.04        67          40
# 3     Cape Town -33.9258   18.4232     78.12        46           0
# 4     Berezovka  53.7214   25.4993     32.43        97         100
# 5        Cheney  47.4874 -117.5758     23.63        95         100
# 6          Hilo  19.7297 -155.0900     67.12        75           0
# 7        Hobart -42.8794  147.3294     64.11        83         100
# 8     Tazovskiy  67.4667   78.7000      3.07        95          99
# 9         Amapa   1.0000  -52.0000     78.15        80         100
#
#    Wind Speed Country      Current Description
# 0        2.15      PH          overcast clouds
# 1        4.61      MU            broken clouds
# 2       13.80      SJ         scattered clouds
# 3       29.93      ZA                clear sky
# 4       17.20      BY               light snow
# 5        9.22      US                     mist
# 6        6.91      US                clear sky
# 7       11.50      AU  light intensity drizzle
# 8       10.54      RU          overcast clouds
# 9        3.74      BR          overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 
                    'Max Temp', 'Humidity', 'Cloudiness',
                    'Wind Speed', 'Current Description']

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  General Luna      PH  13.6881  122.1708     75.56        90          87
# 1      Souillac      MU -20.5167   57.5167     80.98        74          75
# 2  Longyearbyen      SJ  78.2186   15.6401     12.04        67          40
# 3     Cape Town      ZA -33.9258   18.4232     78.12        46           0
# 4     Berezovka      BY  53.7214   25.4993     32.43        97         100
#
#    Wind Speed Current Description
# 0        2.15     overcast clouds
# 1        4.61       broken clouds
# 2       13.80    scattered clouds
# 3       29.93           clear sky
# 4       17.20          light snow

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
